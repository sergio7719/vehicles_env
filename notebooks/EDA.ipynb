# %%
import pandas as pd
import plotly.express as px
import streamlit as st

# %%
# importacon de los datos

vehicles_data = pd.read_csv('vehicles_us.csv')

vehicles_data.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
#validar si hay filas en blanco

vehicles_data.isna().sum()
#Completar los NAN
vehicles_data.fillna('Unknow', inplace = True)
vehicles_data.isna().sum()
vehicles_data.head()
# Out:
# C:\Users\sergio.berlanga\AppData\Local\Temp\ipykernel_18420\2632225709.py:5: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Unknow' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#    price model_year           model  condition cylinders fuel  odometer  \
# 0   9400     2011.0          bmw x5       good       6.0  gas  145000.0
# 1  25500     Unknow      ford f-150       good       6.0  gas   88705.0
# 2   5500     2013.0  hyundai sonata   like new       4.0  gas  110000.0
# 3   1500     2003.0      ford f-150       fair       8.0  gas    Unknow
# 4  14900     2017.0    chrysler 200  excellent       4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV      Unknow     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# ...

# %%
hist_button = st.button('Construir histograma') 

     # crear un histograma
fig = px.histogram(vehicles_data, x="model_year")
        
            # mostrar un gráfico Plotly interactivo
st.plotly_chart(fig, use_container_width=True) 

fig.show()

# %%
fig = px.scatter(vehicles_data, x="model", y="price") # crear un gráfico de dispersión
fig.show() # crear gráfico de dispersión
